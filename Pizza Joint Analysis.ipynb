# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     openssl-1.1.1c             |       h516909a_0         2.1 MB  conda-forge
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     certifi-2019.6.16          |           py36_1         149 KB  conda-forge
#     ca-certificates-2019.6.16  |       hecc5488_0         145 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.49-py_0         conda-forge
#     geopy:           1.20.0-py_0       conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.5.15-0                   --> 2019.6.16-hecc5488_0 conda-forge
#     certifi:         2019.6.16-py36_0              --> 2019.6.16-py36_1     conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.1.1c-h7b6447c_1             --> 1.1.1c-h516909a_0    conda-forge
#
#
# Downloading and Extracting Packages
# geographiclib-1.49   | 32 KB     | ##################################### | 100%
# openssl-1.1.1c       | 2.1 MB    | ##################################### | 100%
# geopy-1.20.0         | 57 KB     | ##################################### | 100%
# certifi-2019.6.16    | 149 KB    | ##################################### | 100%
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     altair-3.1.0               |           py36_0         724 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         822 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  3.1.0-py36_0 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
#
# Downloading and Extracting Packages
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# altair-3.1.0         | 724 KB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'UKVS1LSMR1FGFSOH5TRU14AMU5EP4ZQ2MHKRN5AAS1LVLYUK' # your Foursquare ID
CLIENT_SECRET = '1L4L0J3XJCQ1ZLXRVL0OPA0XUYEXEVNL31JDYC0BY2STLOD5' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: UKVS1LSMR1FGFSOH5TRU14AMU5EP4ZQ2MHKRN5AAS1LVLYUK
# CLIENT_SECRET:1L4L0J3XJCQ1ZLXRVL0OPA0XUYEXEVNL31JDYC0BY2STLOD5

# %%
address = '623 E Adams St, Phoenix, AZ'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 33.44917625 -112.0656412

# %%
search_query = 'pizza'
radius = 400000
print(search_query + ' .... OK!')
# Out:
# pizza .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=UKVS1LSMR1FGFSOH5TRU14AMU5EP4ZQ2MHKRN5AAS1LVLYUK&client_secret=1L4L0J3XJCQ1ZLXRVL0OPA0XUYEXEVNL31JDYC0BY2STLOD5&ll=33.44917625,-112.0656412&v=20180604&query=pizza&radius=400000&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d42350fa197930038b7526a'},
#  'response': {'venues': [{'id': '531bba89498e8d2162be9ef8',
#     'name': 'Pizza Studio - Cityscape',
#     'location': {'address': '11 W Washington St Ste 120',
#      'lat': 33.447972281212955,
#      'lng': -112.07410333452935,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.447972281212955,
#        'lng': -112.07410333452935}],
#      'distance': 797,
#      'postalCode': '85003',
#      'cc': 'US',
#      'city': 'Phoenix',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['11 W Washington St Ste 120',
#       'Phoenix, AZ 85003',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4f11e94ae4b0f2c211ea1912',
#     'name': 'Downtown Pizza Lounge',
#     'location': {'address': '144 E Washington St',
#      'crossStreet': 'by Washington St',
#      'lat': 33.448428513298914,
#      'lng': -112.07141951910468,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.448428513298914,
#        'lng': -112.07141951910468}],
#      'distance': 543,
#      'postalCode': '85004',
#      'cc': 'US',
#      'city': 'Phoenix',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['144 E Washington St (by Washington St)',
#       'Phoenix, AZ 85004',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4fc28d75e4b0524b5cc46ab0',
#     'name': 'Streets Of New York Pizza',
#     'location': {'address': '401 E Jefferson St',
#      'lat': 33.445515416155004,
#      'lng': -112.06622242927551,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.445515416155004,
#        'lng': -112.06622242927551}],
#      'distance': 411,
#      'postalCode': '85004',
#      'cc': 'US',
#      'city': 'Phoenix',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['401 E Jefferson St',
#       'Phoenix, AZ 85004',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4b7f4857f964a520b92430e3',
#     'name': 'Brooklyn NYC Pizza',
#     'location': {'address': '201 E Washington St',
#      'crossStreet': 'at 2nd St.',
#      'lat': 33.447717213075926,
#      'lng': -112.07137578239684,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.447717213075926,
#        'lng': -112.07137578239684}],
#      'distance': 556,
#      'postalCode': '85004',
#      'cc': 'US',
#      'city': 'Phoenix',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['201 E Washington St (at 2nd St.)',
#       'Phoenix, AZ 85004',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4f2c23ace4b0dd6b77c536bd',
#     'name': 'Pizza People',
#     'location': {'address': '1326 N Central Ave',
#      'lat': 33.45589803182215,
#      'lng': -112.07349494004549,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.45589803182215,
#        'lng': -112.07349494004549}],
#      'distance': 1044,
#      'postalCode': '85004',
#      'cc': 'US',
#      'city': 'Phoenix',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['1326 N Central Ave',
#       'Phoenix, AZ 85004',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4bfec16ee584c9285b2f6d25',
#     'name': 'Pizza Hut',
#     'location': {'address': '702 N 1st St',
#      'lat': 33.4510721,
#      'lng': -112.0747304,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.4510721,
#        'lng': -112.0747304}],
#      'distance': 870,
#      'postalCode': '85004',
#      'cc': 'US',
#      'city': 'Phoenix',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['702 N 1st St',
#       'Phoenix, AZ 85004',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4a8efca0f964a520761320e3',
#     'name': "Pino's Pizza al Centro",
#     'location': {'address': '139 W Thomas Rd',
#      'lat': 33.47999158959136,
#      'lng': -112.07585949867563,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.47999158959136,
#        'lng': -112.07585949867563}],
#      'distance': 3559,
#      'postalCode': '85013',
#      'cc': 'US',
#      'city': 'Phoenix',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['139 W Thomas Rd',
#       'Phoenix, AZ 85013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4a7b9b2df964a52086eb1fe3',
#     'name': 'Pizza a Metro',
#     'location': {'address': '2336 W Thomas Rd',
#      'lat': 33.48093620611927,
#      'lng': -112.11018547427994,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.48093620611927,
#        'lng': -112.11018547427994}],
#      'distance': 5441,
#      'postalCode': '85015',
#      'cc': 'US',
#      'city': 'Phoenix',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['2336 W Thomas Rd',
#       'Phoenix, AZ 85015',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '534c3910498ea95153e68115',
#     'name': 'Boka Pizza',
#     'location': {'address': '455 N 3rd St',
#      'crossStreet': '3rd St and Van Buren',
#      'lat': 33.45246120454474,
#      'lng': -112.06943549221059,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.45246120454474,
#        'lng': -112.06943549221059}],
#      'distance': 507,
#      'postalCode': '85004',
#      'cc': 'US',
#      'city': 'Phoenix',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['455 N 3rd St (3rd St and Van Buren)',
#       'Phoenix, AZ 85004',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '99023690'},
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '413ba880f964a520221b1fe3',
#     'name': 'California Pizza Kitchen',
#     'location': {'address': '2400 E. Camelback Rd., Ste. 112, Biltmore',
#      'crossStreet': 'at Biltmore Fashion Park',
#      'lat': 33.510599,
#      'lng': -112.029753,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.510599,
#        'lng': -112.029753}],
#      'distance': 7606,
#      'postalCode': '85016',
#      'cc': 'US',
#      'city': 'Phoenix',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['2400 E. Camelback Rd., Ste. 112, Biltmore (at Biltmore Fashion Park)',
#       'Phoenix, AZ 85016',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '325709',
#      'url': 'https://www.grubhub.com/restaurant/california-pizza-kitchen-2400-e-camelback-rd-ste-112-phoenix/325709?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=325709',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4b05e467f964a5203ce522e3',
#     'name': "Oregano's Pizza Bistro",
#     'location': {'address': '3102 N Scottsdale Rd',
#      'lat': 33.4832930833357,
#      'lng': -111.92657910018407,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.4832930833357,
#        'lng': -111.92657910018407}],
#      'distance': 13460,
#      'postalCode': '85251',
#      'cc': 'US',
#      'city': 'Scottsdale',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['3102 N Scottsdale Rd',
#       'Scottsdale, AZ 85251',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4c464825cd5ca593be6b0087',
#     'name': 'Peter Piper Pizza',
#     'location': {'address': '3403 N. 7th Ave.',
#      'crossStreet': 'at Osborn Rd.',
#      'lat': 33.488436,
#      'lng': -112.082476,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.488436,
#        'lng': -112.082476}],
#      'distance': 4641,
#      'postalCode': '85013',
#      'cc': 'US',
#      'city': 'Phoenix',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['3403 N. 7th Ave. (at Osborn Rd.)',
#       'Phoenix, AZ 85013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4b5e6909f964a520818d29e3',
#     'name': 'Otto Pizza and Pastry',
#     'location': {'address': '804 S Ash Ave',
#      'crossStreet': 'at W University Dr',
#      'lat': 33.4214432017089,
#      'lng': -111.94249344660533,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.4214432017089,
#        'lng': -111.94249344660533}],
#      'distance': 11849,
#      'postalCode': '85281',
#      'cc': 'US',
#      'city': 'Tempe',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['804 S Ash Ave (at W University Dr)',
#       'Tempe, AZ 85281',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4b62c2fef964a5209f512ae3',
#     'name': "Gus's New York Style Pizza",
#     'location': {'address': '933 E University Dr',
#      'crossStreet': 'Rural and University',
#      'lat': 33.42119849782374,
#      'lng': -111.92505934702277,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.42119849782374,
#        'lng': -111.92505934702277}],
#      'distance': 13425,
#      'postalCode': '85281',
#      'cc': 'US',
#      'city': 'Tempe',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['933 E University Dr (Rural and University)',
#       'Tempe, AZ 85281',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '76213',
#      'url': 'https://www.grubhub.com/restaurant/guss-new-york-pizza-829-s-rural-rd-tempe/76213?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=76213',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'venuePage': {'id': '90485104'},
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4ce862d2595cb1f77799c814',
#     'name': "Papa John's Pizza",
#     'location': {'address': '2836 E Indian School Rd',
#      'lat': 33.4956091,
#      'lng': -112.0200316,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.4956091,
#        'lng': -112.0200316}],
#      'distance': 6682,
#      'postalCode': '85016',
#      'cc': 'US',
#      'city': 'Phoenix',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['2836 E Indian School Rd',
#       'Phoenix, AZ 85016',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '598939',
#      'url': 'https://www.grubhub.com/restaurant/papa-johns-pizza-2836-e-indian-school-rd-phoenix/598939?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=598939',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4b8327c4f964a520befa30e3',
#     'name': 'Peter Piper Pizza',
#     'location': {'address': '3945 East Thomas Road',
#      'crossStreet': 'at 40th St.',
#      'lat': 33.480027,
#      'lng': -111.996145,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.480027,
#        'lng': -111.996145}],
#      'distance': 7310,
#      'postalCode': '85018',
#      'cc': 'US',
#      'city': 'Phoenix',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['3945 East Thomas Road (at 40th St.)',
#       'Phoenix, AZ 85018',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4b9b1ab8f964a52001f335e3',
#     'name': 'Peter Piper Pizza',
#     'location': {'address': '6040 South Central Avenue',
#      'crossStreet': 'Central & southern',
#      'lat': 33.390869,
#      'lng': -112.074627,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.390869,
#        'lng': -112.074627}],
#      'distance': 6544,
#      'postalCode': '85041',
#      'cc': 'US',
#      'city': 'Phoenix',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['6040 South Central Avenue (Central & southern)',
#       'Phoenix, AZ 85041',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4c9423f36b35a14307f618dc',
#     'name': 'Little Caesars Pizza',
#     'location': {'address': '1615 W Camelback Rd',
#      'lat': 33.50854971778468,
#      'lng': -112.09446518712464,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.50854971778468,
#        'lng': -112.09446518712464}],
#      'distance': 7130,
#      'postalCode': '85015',
#      'cc': 'US',
#      'city': 'Phoenix',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['1615 W Camelback Rd',
#       'Phoenix, AZ 85015',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4a2ed00ff964a5205d981fe3',
#     'name': 'California Pizza Kitchen',
#     'location': {'address': '2000 E. Rio Salado Pkwy., Ste. 1253, Tempe Marketplace',
#      'crossStreet': 'at Tempe Marketplace',
#      'lat': 33.433006,
#      'lng': -111.90313,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.433006,
#        'lng': -111.90313}],
#      'distance': 15202,
#      'postalCode': '85281',
#      'cc': 'US',
#      'city': 'Tempe',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['2000 E. Rio Salado Pkwy., Ste. 1253, Tempe Marketplace (at Tempe Marketplace)',
#       'Tempe, AZ 85281',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '325857',
#      'url': 'https://www.grubhub.com/restaurant/california-pizza-kitchen-2000-e-rio-salado-pkwy-ste-1253-tempe/325857?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=325857',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4ba42eb6f964a520bd8938e3',
#     'name': 'Little Caesars Pizza',
#     'location': {'address': '4340 W McDowell Rd Ste 6',
#      'lat': 33.466216921806335,
#      'lng': -112.15346932411194,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.466216921806335,
#        'lng': -112.15346932411194}],
#      'distance': 8374,
#      'postalCode': '85035',
#      'cc': 'US',
#      'city': 'Phoenix',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['4340 W McDowell Rd Ste 6',
#       'Phoenix, AZ 85035',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '532d2102498e17447218942c',
#     'name': '414 Pub & Pizza',
#     'location': {'address': '414 S Mill Ave',
#      'lat': 33.42610730368834,
#      'lng': -111.9401242793037,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.42610730368834,
#        'lng': -111.9401242793037}],
#      'distance': 11939,
#      'postalCode': '85281',
#      'cc': 'US',
#      'city': 'Tempe',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['414 S Mill Ave',
#       'Tempe, AZ 85281',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '308657',
#      'url': 'https://www.grubhub.com/restaurant/414-new-york-pizza-414-s-mill-ave-ste-118-tempe/308657?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=308657',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '5100a5fce4b058a37daa7b68',
#     'name': 'New York Pizza Dept.',
#     'location': {'address': 'Phoenix Sky Harbor International Airport',
#      'crossStreet': 'Terminal 4 (Gates B1-B14)',
#      'lat': 33.437729848743444,
#      'lng': -111.99676463084883,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.437729848743444,
#        'lng': -111.99676463084883}],
#      'distance': 6523,
#      'postalCode': '85034',
#      'cc': 'US',
#      'city': 'Phoenix',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['Phoenix Sky Harbor International Airport (Terminal 4 (Gates B1-B14))',
#       'Phoenix, AZ 85034',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4b1c59b4f964a5206c0624e3',
#     'name': 'NYPD Pizza',
#     'location': {'address': '1949 E Camelback Rd Ste 144',
#      'crossStreet': 'Camelback and 20th st',
#      'lat': 33.50751311172204,
#      'lng': -112.04094211717755,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.50751311172204,
#        'lng': -112.04094211717755}],
#      'distance': 6887,
#      'postalCode': '85016',
#      'cc': 'US',
#      'city': 'Phoenix',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['1949 E Camelback Rd Ste 144 (Camelback and 20th st)',
#       'Phoenix, AZ 85016',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4c05a7e28f8fa593cc39f20d',
#     'name': 'Little Caesars Pizza',
#     'location': {'address': '2434 E. Baseline Rd #103 Legacy Plaza',
#      'lat': 33.3785919342333,
#      'lng': -112.02870347006451,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.3785919342333,
#        'lng': -112.02870347006451}],
#      'distance': 8574,
#      'postalCode': '85042',
#      'cc': 'US',
#      'city': 'Phoenix',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['2434 E. Baseline Rd #103 Legacy Plaza',
#       'Phoenix, AZ 85042',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4be77720ee96c9280018fdbf',
#     'name': 'Peter Piper Pizza',
#     'location': {'address': '4315 West Glendale Avenue',
#      'lat': 33.537068,
#      'lng': -112.152021,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.537068,
#        'lng': -112.152021}],
#      'distance': 12650,
#      'postalCode': '85301',
#      'cc': 'US',
#      'city': 'Glendale',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['4315 West Glendale Avenue',
#       'Glendale, AZ 85301',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4bcbaa6fcc8cd13acaeabfcf',
#     'name': "Joe's New York Pizza",
#     'location': {'address': '7321 E Shoeman Ln',
#      'crossStreet': 'at N Wells Fargo Ave',
#      'lat': 33.50051,
#      'lng': -111.92329,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.50051,
#        'lng': -111.92329}],
#      'distance': 14400,
#      'postalCode': '85251',
#      'cc': 'US',
#      'city': 'Scottsdale',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['7321 E Shoeman Ln (at N Wells Fargo Ave)',
#       'Scottsdale, AZ 85251',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '312702',
#      'url': 'https://www.grubhub.com/restaurant/joes-new-york-pizza-7321-e-shoeman-ln-scottsdale/312702?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=312702',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'venuePage': {'id': '35707362'},
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4bd6841c5631c9b6740ca630',
#     'name': 'Pullanos Pizza & Wings',
#     'location': {'address': '13848 N 51st Ave',
#      'crossStreet': 'at W. Thunderbird Rd.',
#      'lat': 33.612112191773335,
#      'lng': -112.16908647593783,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.612112191773335,
#        'lng': -112.16908647593783}],
#      'distance': 20521,
#      'postalCode': '85306',
#      'cc': 'US',
#      'city': 'Glendale',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['13848 N 51st Ave (at W. Thunderbird Rd.)',
#       'Glendale, AZ 85306',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d11d941735',
#       'name': 'Sports Bar',
#       'pluralName': 'Sports Bars',
#       'shortName': 'Sports Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sportsbar_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '33601973'},
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4bee1d756c5c952159f5068a',
#     'name': "Domino's Pizza",
#     'location': {'address': '681 E Apache Blvd Ste 104',
#      'crossStreet': 'at Rural Rd',
#      'lat': 33.41423434281571,
#      'lng': -111.92894348505433,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.41423434281571,
#        'lng': -111.92894348505433}],
#      'distance': 13281,
#      'postalCode': '85281',
#      'cc': 'US',
#      'city': 'Tempe',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['681 E Apache Blvd Ste 104 (at Rural Rd)',
#       'Tempe, AZ 85281',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4c1edab7fcf8c9b6faf3ad0b',
#     'name': 'Little Caesars Pizza',
#     'location': {'address': '8929 N Central Ave #101',
#      'lat': 33.56702209186157,
#      'lng': -112.07338391472682,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.56702209186157,
#        'lng': -112.07338391472682}],
#      'distance': 13138,
#      'postalCode': '85020',
#      'cc': 'US',
#      'city': 'Phoenix',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['8929 N Central Ave #101',
#       'Phoenix, AZ 85020',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4b64a01ff964a52060c32ae3',
#     'name': 'Little Caesars Pizza',
#     'location': {'address': '711 E. Broadway',
#      'lat': 33.40724786590066,
#      'lng': -111.92717080860317,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.40724786590066,
#        'lng': -111.92717080860317}],
#      'distance': 13685,
#      'postalCode': '85282',
#      'cc': 'US',
#      'city': 'Tempe',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['711 E. Broadway',
#       'Tempe, AZ 85282',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4c338e1c3896e21ec53aea90',
#     'name': 'Peter Piper Pizza',
#     'location': {'address': '7607 East McDowell Road',
#      'crossStreet': 'McDowell & Miller',
#      'lat': 33.465398,
#      'lng': -111.916691,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.465398,
#        'lng': -111.916691}],
#      'distance': 13950,
#      'postalCode': '85257',
#      'cc': 'US',
#      'city': 'Scottsdale',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['7607 East McDowell Road (McDowell & Miller)',
#       'Scottsdale, AZ 85257',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4b0045c9f964a520323c22e3',
#     'name': 'Peter Piper Pizza',
#     'location': {'address': '6821 West Peoria Avenue',
#      'crossStreet': '67th and Peoria',
#      'lat': 33.580558,
#      'lng': -112.206319,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.580558,
#        'lng': -112.206319}],
#      'distance': 19605,
#      'postalCode': '85345',
#      'cc': 'US',
#      'city': 'Peoria',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['6821 West Peoria Avenue (67th and Peoria)',
#       'Peoria, AZ 85345',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4dd3fb1b091afbe9b9cce360',
#     'name': "Oregano's Pizza Bistro",
#     'location': {'address': '4602 E Cactus Rd',
#      'crossStreet': 'at Paradise Valley Mall',
#      'lat': 33.599713926362526,
#      'lng': -111.98226036196345,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.599713926362526,
#        'lng': -111.98226036196345}],
#      'distance': 18457,
#      'postalCode': '85032',
#      'cc': 'US',
#      'city': 'Phoenix',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['4602 E Cactus Rd (at Paradise Valley Mall)',
#       'Phoenix, AZ 85032',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4baac656f964a520d4853ae3',
#     'name': 'Little Caesars Pizza',
#     'location': {'address': '7919 E. Thomas Road Indian River Plaza',
#      'lat': 33.47890295397645,
#      'lng': -111.90934713314984,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.47890295397645,
#        'lng': -111.90934713314984}],
#      'distance': 14886,
#      'postalCode': '85251',
#      'cc': 'US',
#      'city': 'Scottsdale',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['7919 E. Thomas Road Indian River Plaza',
#       'Scottsdale, AZ 85251',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4adaae3ef964a520082421e3',
#     'name': 'Peter Piper Pizza',
#     'location': {'address': '4024 N. 67th Ave.',
#      'crossStreet': 'Indian School Rd',
#      'lat': 33.494128,
#      'lng': -112.204508,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.494128,
#        'lng': -112.204508}],
#      'distance': 13831,
#      'postalCode': '85033',
#      'cc': 'US',
#      'city': 'Phoenix',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['4024 N. 67th Ave. (Indian School Rd)',
#       'Phoenix, AZ 85033',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4a85b24ff964a520f1fe1fe3',
#     'name': 'Slices Pizza',
#     'location': {'address': '11 E 6th St',
#      'crossStreet': 'at Mill Ave',
#      'lat': 33.42425779859654,
#      'lng': -111.93953742790865,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.42425779859654,
#        'lng': -111.93953742790865}],
#      'distance': 12038,
#      'postalCode': '85281',
#      'cc': 'US',
#      'city': 'Tempe',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['11 E 6th St (at Mill Ave)',
#       'Tempe, AZ 85281',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1182770',
#      'url': 'https://www.grubhub.com/restaurant/slices-on-mill-11-e-6th-st-ste-102-tempe/1182770?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1182770',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'venuePage': {'id': '33037277'},
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4ae5eb15f964a52026a321e3',
#     'name': 'Peter Piper Pizza',
#     'location': {'address': '9620 N. Metro Pkwy. West',
#      'lat': 33.57431,
#      'lng': -112.125745,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.57431,
#        'lng': -112.125745}],
#      'distance': 15005,
#      'postalCode': '85051',
#      'cc': 'US',
#      'city': 'Phoenix',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['9620 N. Metro Pkwy. West',
#       'Phoenix, AZ 85051',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4bea000261aca5938a508300',
#     'name': 'Peter Piper Pizza',
#     'location': {'address': '1805 E. Baseline Rd.',
#      'crossStreet': 'Baseline Rd. & McClintock Dr.',
#      'lat': 33.377489,
#      'lng': -111.908294,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.377489,
#        'lng': -111.908294}],
#      'distance': 16656,
#      'postalCode': '85282',
#      'cc': 'US',
#      'city': 'Tempe',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['1805 E. Baseline Rd. (Baseline Rd. & McClintock Dr.)',
#       'Tempe, AZ 85282',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4b4c91dcf964a5206ab626e3',
#     'name': "Oregano's Pizza Bistro",
#     'location': {'address': '1130 S Dobson Rd',
#      'crossStreet': 'at W Southern Ave',
#      'lat': 33.39406686290346,
#      'lng': -111.87515722552065,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.39406686290346,
#        'lng': -111.87515722552065}],
#      'distance': 18731,
#      'postalCode': '85202',
#      'cc': 'US',
#      'city': 'Mesa',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['1130 S Dobson Rd (at W Southern Ave)',
#       'Mesa, AZ 85202',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4b6cdd8af964a520165a2ce3',
#     'name': 'Little Chicago Pizza',
#     'location': {'address': '1645 N Hayden Rd',
#      'crossStreet': 'McDowell and Hayden',
#      'lat': 33.485179016533166,
#      'lng': -111.90842296007762,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.485179016533166,
#        'lng': -111.90842296007762}],
#      'distance': 15139,
#      'postalCode': '85257',
#      'cc': 'US',
#      'city': 'Scottsdale',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['1645 N Hayden Rd (McDowell and Hayden)',
#       'Scottsdale, AZ 85257',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4b00adc2f964a520884022e3',
#     'name': "Buono's New York Style Pizza",
#     'location': {'address': '2023 W Guadalupe Rd',
#      'crossStreet': 'Dobson',
#      'lat': 33.3629126567022,
#      'lng': -111.87747014484404,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.3629126567022,
#        'lng': -111.87747014484404}],
#      'distance': 19949,
#      'postalCode': '85202',
#      'cc': 'US',
#      'city': 'Mesa',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['2023 W Guadalupe Rd (Dobson)',
#       'Mesa, AZ 85202',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4b463d99f964a5201f1b26e3',
#     'name': 'California Pizza Kitchen',
#     'location': {'address': '10100 N. Scottsdale Rd., Scottsdale',
#      'crossStreet': 'at Gold Dust Ave',
#      'lat': 33.578008,
#      'lng': -111.926876,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.578008,
#        'lng': -111.926876}],
#      'distance': 19275,
#      'postalCode': '85253',
#      'cc': 'US',
#      'city': 'Scottsdale',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['10100 N. Scottsdale Rd., Scottsdale (at Gold Dust Ave)',
#       'Scottsdale, AZ 85253',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '325748',
#      'url': 'https://www.grubhub.com/restaurant/california-pizza-kitchen-10100-scottsdale-rd-paradise-valley/325748?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=325748',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4b4cbd61f964a520b3bc26e3',
#     'name': "Floridino's Pizza & Pasta",
#     'location': {'address': '590 N Alma School Rd',
#      'crossStreet': 'btw W. Galveston St. & W. Erie St.',
#      'lat': 33.31135611600117,
#      'lng': -111.85966026451149,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.31135611600117,
#        'lng': -111.85966026451149}],
#      'distance': 24535,
#      'postalCode': '85224',
#      'cc': 'US',
#      'city': 'Chandler',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['590 N Alma School Rd (btw W. Galveston St. & W. Erie St.)',
#       'Chandler, AZ 85224',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '211631',
#      'url': 'https://www.grubhub.com/restaurant/floridinos-pizza--pasta-590-n-alma-school-rd-ste-35-chandler/211631?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=211631',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'venuePage': {'id': '64346150'},
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4bbe8a5f85fbb71324037167',
#     'name': 'Little Caesars Pizza',
#     'location': {'address': '967 E Guadalupe Rd',
#      'lat': 33.36334835991079,
#      'lng': -111.92691305897185,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.36334835991079,
#        'lng': -111.92691305897185}],
#      'distance': 16046,
#      'postalCode': '85283',
#      'cc': 'US',
#      'city': 'Tempe',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['967 E Guadalupe Rd',
#       'Tempe, AZ 85283',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '559f253e498e2286fab5e979',
#     'name': "Don's NY Pizza",
#     'location': {'address': '7539 W Peoria Ave',
#      'crossStreet': 'at N 75th Ave',
#      'lat': 33.58027376786494,
#      'lng': -112.22102764376156,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.58027376786494,
#        'lng': -112.22102764376156}],
#      'distance': 20517,
#      'postalCode': '85345',
#      'cc': 'US',
#      'city': 'Peoria',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['7539 W Peoria Ave (at N 75th Ave)',
#       'Peoria, AZ 85345',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4bafa21bf964a52007123ce3',
#     'name': 'Taco Bell / Pizza Hut',
#     'location': {'address': '5800 W Chandler Blvd',
#      'crossStreet': 'at N Gila Springs Blvd',
#      'lat': 33.305964,
#      'lng': -111.942242,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.305964,
#        'lng': -111.942242}],
#      'distance': 19640,
#      'postalCode': '85226',
#      'cc': 'US',
#      'city': 'Chandler',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['5800 W Chandler Blvd (at N Gila Springs Blvd)',
#       'Chandler, AZ 85226',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '924541',
#      'url': 'https://www.grubhub.com/restaurant/taco-bell-5800-w-chandler-blvd-chandler/924541?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=924541',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4d56d970ba5b224b6a1d2014',
#     'name': "Oregano's Pizza Bistro",
#     'location': {'address': '1960 W Germann Rd',
#      'crossStreet': 'at Dobson Rd',
#      'lat': 33.27762782031286,
#      'lng': -111.87569630167877,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.27762782031286,
#        'lng': -111.87569630167877}],
#      'distance': 26010,
#      'postalCode': '85286',
#      'cc': 'US',
#      'city': 'Chandler',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['1960 W Germann Rd (at Dobson Rd)',
#       'Chandler, AZ 85286',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4b591cf1f964a520327d28e3',
#     'name': 'California Pizza Kitchen',
#     'location': {'address': '3163 W. Chandler Blvd.',
#      'lat': 33.299807,
#      'lng': -111.898881,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.299807,
#        'lng': -111.898881}],
#      'distance': 22733,
#      'postalCode': '85226',
#      'cc': 'US',
#      'city': 'Chandler',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['3163 W. Chandler Blvd.',
#       'Chandler, AZ 85226',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '332434',
#      'url': 'https://www.grubhub.com/restaurant/california-pizza-kitchen-3163-w-chandler-blvd-chandler/332434?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=332434',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4b214d1cf964a520d03924e3',
#     'name': 'Peter Piper Pizza',
#     'location': {'address': '10170 W. McDowell Rd.',
#      'crossStreet': 'btwn 103rd & 99th',
#      'lat': 33.466123,
#      'lng': -112.278459,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.466123,
#        'lng': -112.278459}],
#      'distance': 19854,
#      'postalCode': '85392',
#      'cc': 'US',
#      'city': 'Avondale',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['10170 W. McDowell Rd. (btwn 103rd & 99th)',
#       'Avondale, AZ 85392',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564620047',
#     'hasPerk': False},
#    {'id': '4b1eade6f964a520b11d24e3',
#     'name': "Barro's Pizza",
#     'location': {'address': '2510 W Thunderbird Rd #6',
#      'lat': 33.6114231,
#      'lng': -112.1101285,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.6114231,
#        'lng': -112.1101285}],
#      'distance': 18526,
#      'postalCode': '85023',
#      'cc': 'US',
#      'city': 'Phoenix',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['2510 W Thunderbird Rd #6',
#       'Phoenix, AZ 85023',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564620047',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories delivery.id  \
# 0  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...         NaN
# 1  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...         NaN
# 2  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...         NaN
# 3  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...         NaN
# 4  [{'id': '4bf58dd8d48988d1cb941735', 'name': 'F...         NaN
#
#   delivery.provider.icon.name delivery.provider.icon.prefix  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
#
#   delivery.provider.icon.sizes delivery.provider.name delivery.url  hasPerk  \
# 0                          NaN                    NaN          NaN    False
# 1                          NaN                    NaN          NaN    False
# 2                          NaN                    NaN          NaN    False
# 3                          NaN                    NaN          NaN    False
# 4                          NaN                    NaN          NaN    False
#
#                          id            location.address  ...  \
# 0  531bba89498e8d2162be9ef8  11 W Washington St Ste 120  ...
# 1  4f11e94ae4b0f2c211ea1912         144 E Washington St  ...
# 2  4fc28d75e4b0524b5cc46ab0          401 E Jefferson St  ...
# 3  4b7f4857f964a520b92430e3         201 E Washington St  ...
# 4  4f2c23ace4b0dd6b77c536bd          1326 N Central Ave  ...
#
#   location.distance                          location.formattedAddress  \
# 0               797  [11 W Washington St Ste 120, Phoenix, AZ 85003...
# 1               543  [144 E Washington St (by Washington St), Phoen...
# 2               411  [401 E Jefferson St, Phoenix, AZ 85004, United...
# 3               556  [201 E Washington St (at 2nd St.), Phoenix, AZ...
# 4              1044  [1326 N Central Ave, Phoenix, AZ 85004, United...
#
#                              location.labeledLatLngs location.lat  \
# 0  [{'label': 'display', 'lat': 33.44797228121295...    33.447972
# 1  [{'label': 'display', 'lat': 33.44842851329891...    33.448429
# 2  [{'label': 'display', 'lat': 33.44551541615500...    33.445515
# 3  [{'label': 'display', 'lat': 33.44771721307592...    33.447717
# 4  [{'label': 'display', 'lat': 33.45589803182215...    33.455898
#
#    location.lng location.postalCode location.state                       name  \
# 0   -112.074103               85003             AZ   Pizza Studio - Cityscape
# 1   -112.071420               85004             AZ      Downtown Pizza Lounge
# 2   -112.066222               85004             AZ  Streets Of New York Pizza
# 3   -112.071376               85004             AZ         Brooklyn NYC Pizza
# 4   -112.073495               85004             AZ               Pizza People
#
#      referralId venuePage.id
# 0  v-1564620047          NaN
# 1  v-1564620047          NaN
# 2  v-1564620047          NaN
# 3  v-1564620047          NaN
# 4  v-1564620047          NaN
#
# [5 rows x 24 columns]

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                             name            categories  \
# 0       Pizza Studio - Cityscape           Pizza Place
# 1          Downtown Pizza Lounge           Pizza Place
# 2      Streets Of New York Pizza           Pizza Place
# 3             Brooklyn NYC Pizza           Pizza Place
# 4                   Pizza People            Food Truck
# 5                      Pizza Hut           Pizza Place
# 6         Pino's Pizza al Centro           Pizza Place
# 7                  Pizza a Metro           Pizza Place
# 8                     Boka Pizza           Pizza Place
# 9       California Pizza Kitchen           Pizza Place
# 10        Oregano's Pizza Bistro           Pizza Place
# 11             Peter Piper Pizza           Pizza Place
# 12         Otto Pizza and Pastry           Pizza Place
# 13    Gus's New York Style Pizza           Pizza Place
# 14             Papa John's Pizza           Pizza Place
# 15             Peter Piper Pizza           Pizza Place
# 16             Peter Piper Pizza           Pizza Place
# 17          Little Caesars Pizza           Pizza Place
# 18      California Pizza Kitchen           Pizza Place
# 19          Little Caesars Pizza           Pizza Place
# 20               414 Pub & Pizza           Pizza Place
# 21          New York Pizza Dept.           Pizza Place
# 22                    NYPD Pizza           Pizza Place
# 23          Little Caesars Pizza           Pizza Place
# 24             Peter Piper Pizza           Pizza Place
# 25          Joe's New York Pizza           Pizza Place
# 26        Pullanos Pizza & Wings            Sports Bar
# 27                Domino's Pizza           Pizza Place
# 28          Little Caesars Pizza           Pizza Place
# 29          Little Caesars Pizza           Pizza Place
# 30             Peter Piper Pizza           Pizza Place
# 31             Peter Piper Pizza           Pizza Place
# 32        Oregano's Pizza Bistro           Pizza Place
# 33          Little Caesars Pizza           Pizza Place
# 34             Peter Piper Pizza           Pizza Place
# 35                  Slices Pizza           Pizza Place
# 36             Peter Piper Pizza           Pizza Place
# 37             Peter Piper Pizza           Pizza Place
# 38        Oregano's Pizza Bistro           Pizza Place
# 39          Little Chicago Pizza           Pizza Place
# 40  Buono's New York Style Pizza           Pizza Place
# 41      California Pizza Kitchen           Pizza Place
# 42     Floridino's Pizza & Pasta    Italian Restaurant
# 43          Little Caesars Pizza           Pizza Place
# 44                Don's NY Pizza           Pizza Place
# 45         Taco Bell / Pizza Hut  Fast Food Restaurant
# 46        Oregano's Pizza Bistro           Pizza Place
# 47      California Pizza Kitchen           Pizza Place
# 48             Peter Piper Pizza           Pizza Place
# 49                 Barro's Pizza           Pizza Place
#
#                                               address  cc        city  \
# 0                          11 W Washington St Ste 120  US     Phoenix
# 1                                 144 E Washington St  US     Phoenix
# 2                                  401 E Jefferson St  US     Phoenix
# 3                                 201 E Washington St  US     Phoenix
# 4                                  1326 N Central Ave  US     Phoenix
# 5                                        702 N 1st St  US     Phoenix
# 6                                     139 W Thomas Rd  US     Phoenix
# 7                                    2336 W Thomas Rd  US     Phoenix
# 8                                        455 N 3rd St  US     Phoenix
# 9           2400 E. Camelback Rd., Ste. 112, Biltmore  US     Phoenix
# 10                               3102 N Scottsdale Rd  US  Scottsdale
# 11                                   3403 N. 7th Ave.  US     Phoenix
# 12                                      804 S Ash Ave  US       Tempe
# 13                                933 E University Dr  US       Tempe
# 14                            2836 E Indian School Rd  US     Phoenix
# 15                              3945 East Thomas Road  US     Phoenix
# 16                          6040 South Central Avenue  US     Phoenix
# 17                                1615 W Camelback Rd  US     Phoenix
# 18  2000 E. Rio Salado Pkwy., Ste. 1253, Tempe Mar...  US       Tempe
# 19                           4340 W McDowell Rd Ste 6  US     Phoenix
# 20                                     414 S Mill Ave  US       Tempe
# 21           Phoenix Sky Harbor International Airport  US     Phoenix
# 22                        1949 E Camelback Rd Ste 144  US     Phoenix
# 23              2434 E. Baseline Rd #103 Legacy Plaza  US     Phoenix
# 24                          4315 West Glendale Avenue  US    Glendale
# 25                                  7321 E Shoeman Ln  US  Scottsdale
# 26                                   13848 N 51st Ave  US    Glendale
# 27                          681 E Apache Blvd Ste 104  US       Tempe
# 28                            8929 N Central Ave #101  US     Phoenix
# 29                                    711 E. Broadway  US       Tempe
# 30                            7607 East McDowell Road  US  Scottsdale
# 31                            6821 West Peoria Avenue  US      Peoria
# 32                                   4602 E Cactus Rd  US     Phoenix
# 33             7919 E. Thomas Road Indian River Plaza  US  Scottsdale
# 34                                  4024 N. 67th Ave.  US     Phoenix
# 35                                        11 E 6th St  US       Tempe
# 36                           9620 N. Metro Pkwy. West  US     Phoenix
# 37                               1805 E. Baseline Rd.  US       Tempe
# 38                                   1130 S Dobson Rd  US        Mesa
# 39                                   1645 N Hayden Rd  US  Scottsdale
# 40                                2023 W Guadalupe Rd  US        Mesa
# 41                10100 N. Scottsdale Rd., Scottsdale  US  Scottsdale
# 42                               590 N Alma School Rd  US    Chandler
# 43                                 967 E Guadalupe Rd  US       Tempe
# 44                                  7539 W Peoria Ave  US      Peoria
# 45                               5800 W Chandler Blvd  US    Chandler
# 46                                  1960 W Germann Rd  US    Chandler
# 47                             3163 W. Chandler Blvd.  US    Chandler
# 48                              10170 W. McDowell Rd.  US    Avondale
# 49                           2510 W Thunderbird Rd #6  US     Phoenix
#
#           country                         crossStreet  distance  \
# 0   United States                                 NaN       797
# 1   United States                    by Washington St       543
# 2   United States                                 NaN       411
# 3   United States                          at 2nd St.       556
# 4   United States                                 NaN      1044
# 5   United States                                 NaN       870
# 6   United States                                 NaN      3559
# 7   United States                                 NaN      5441
# 8   United States                3rd St and Van Buren       507
# 9   United States            at Biltmore Fashion Park      7606
# 10  United States                                 NaN     13460
# 11  United States                       at Osborn Rd.      4641
# 12  United States                  at W University Dr     11849
# 13  United States                Rural and University     13425
# 14  United States                                 NaN      6682
# 15  United States                         at 40th St.      7310
# 16  United States                  Central & southern      6544
# 17  United States                                 NaN      7130
# 18  United States                at Tempe Marketplace     15202
# 19  United States                                 NaN      8374
# 20  United States                                 NaN     11939
# 21  United States           Terminal 4 (Gates B1-B14)      6523
# 22  United States               Camelback and 20th st      6887
# 23  United States                                 NaN      8574
# 24  United States                                 NaN     12650
# 25  United States                at N Wells Fargo Ave     14400
# 26  United States               at W. Thunderbird Rd.     20521
# 27  United States                         at Rural Rd     13281
# 28  United States                                 NaN     13138
# 29  United States                                 NaN     13685
# 30  United States                   McDowell & Miller     13950
# 31  United States                     67th and Peoria     19605
# 32  United States             at Paradise Valley Mall     18457
# 33  United States                                 NaN     14886
# 34  United States                    Indian School Rd     13831
# 35  United States                         at Mill Ave     12038
# 36  United States                                 NaN     15005
# 37  United States       Baseline Rd. & McClintock Dr.     16656
# 38  United States                   at W Southern Ave     18731
# 39  United States                 McDowell and Hayden     15139
# 40  United States                              Dobson     19949
# 41  United States                    at Gold Dust Ave     19275
# 42  United States  btw W. Galveston St. & W. Erie St.     24535
# 43  United States                                 NaN     16046
# 44  United States                       at N 75th Ave     20517
# 45  United States              at N Gila Springs Blvd     19640
# 46  United States                        at Dobson Rd     26010
# 47  United States                                 NaN     22733
# 48  United States                   btwn 103rd & 99th     19854
# 49  United States                                 NaN     18526
#
#                                      formattedAddress  \
# 0   [11 W Washington St Ste 120, Phoenix, AZ 85003...
# 1   [144 E Washington St (by Washington St), Phoen...
# 2   [401 E Jefferson St, Phoenix, AZ 85004, United...
# 3   [201 E Washington St (at 2nd St.), Phoenix, AZ...
# 4   [1326 N Central Ave, Phoenix, AZ 85004, United...
# 5    [702 N 1st St, Phoenix, AZ 85004, United States]
# 6   [139 W Thomas Rd, Phoenix, AZ 85013, United St...
# 7   [2336 W Thomas Rd, Phoenix, AZ 85015, United S...
# 8   [455 N 3rd St (3rd St and Van Buren), Phoenix,...
# 9   [2400 E. Camelback Rd., Ste. 112, Biltmore (at...
# 10  [3102 N Scottsdale Rd, Scottsdale, AZ 85251, U...
# 11  [3403 N. 7th Ave. (at Osborn Rd.), Phoenix, AZ...
# 12  [804 S Ash Ave (at W University Dr), Tempe, AZ...
# 13  [933 E University Dr (Rural and University), T...
# 14  [2836 E Indian School Rd, Phoenix, AZ 85016, U...
# 15  [3945 East Thomas Road (at 40th St.), Phoenix,...
# 16  [6040 South Central Avenue (Central & southern...
# 17  [1615 W Camelback Rd, Phoenix, AZ 85015, Unite...
# 18  [2000 E. Rio Salado Pkwy., Ste. 1253, Tempe Ma...
# 19  [4340 W McDowell Rd Ste 6, Phoenix, AZ 85035, ...
# 20   [414 S Mill Ave, Tempe, AZ 85281, United States]
# 21  [Phoenix Sky Harbor International Airport (Ter...
# 22  [1949 E Camelback Rd Ste 144 (Camelback and 20...
# 23  [2434 E. Baseline Rd #103 Legacy Plaza, Phoeni...
# 24  [4315 West Glendale Avenue, Glendale, AZ 85301...
# 25  [7321 E Shoeman Ln (at N Wells Fargo Ave), Sco...
# 26  [13848 N 51st Ave (at W. Thunderbird Rd.), Gle...
# 27  [681 E Apache Blvd Ste 104 (at Rural Rd), Temp...
# 28  [8929 N Central Ave #101, Phoenix, AZ 85020, U...
# 29  [711 E. Broadway, Tempe, AZ 85282, United States]
# 30  [7607 East McDowell Road (McDowell & Miller), ...
# 31  [6821 West Peoria Avenue (67th and Peoria), Pe...
# 32  [4602 E Cactus Rd (at Paradise Valley Mall), P...
# 33  [7919 E. Thomas Road Indian River Plaza, Scott...
# 34  [4024 N. 67th Ave. (Indian School Rd), Phoenix...
# 35  [11 E 6th St (at Mill Ave), Tempe, AZ 85281, U...
# 36  [9620 N. Metro Pkwy. West, Phoenix, AZ 85051, ...
# 37  [1805 E. Baseline Rd. (Baseline Rd. & McClinto...
# 38  [1130 S Dobson Rd (at W Southern Ave), Mesa, A...
# 39  [1645 N Hayden Rd (McDowell and Hayden), Scott...
# 40  [2023 W Guadalupe Rd (Dobson), Mesa, AZ 85202,...
# 41  [10100 N. Scottsdale Rd., Scottsdale (at Gold ...
# 42  [590 N Alma School Rd (btw W. Galveston St. & ...
# 43  [967 E Guadalupe Rd, Tempe, AZ 85283, United S...
# 44  [7539 W Peoria Ave (at N 75th Ave), Peoria, AZ...
# 45  [5800 W Chandler Blvd (at N Gila Springs Blvd)...
# 46  [1960 W Germann Rd (at Dobson Rd), Chandler, A...
# 47  [3163 W. Chandler Blvd., Chandler, AZ 85226, U...
# 48  [10170 W. McDowell Rd. (btwn 103rd & 99th), Av...
# 49  [2510 W Thunderbird Rd #6, Phoenix, AZ 85023, ...
#
#                                        labeledLatLngs        lat         lng  \
# 0   [{'label': 'display', 'lat': 33.44797228121295...  33.447972 -112.074103
# 1   [{'label': 'display', 'lat': 33.44842851329891...  33.448429 -112.071420
# 2   [{'label': 'display', 'lat': 33.44551541615500...  33.445515 -112.066222
# 3   [{'label': 'display', 'lat': 33.44771721307592...  33.447717 -112.071376
# 4   [{'label': 'display', 'lat': 33.45589803182215...  33.455898 -112.073495
# 5   [{'label': 'display', 'lat': 33.4510721, 'lng'...  33.451072 -112.074730
# 6   [{'label': 'display', 'lat': 33.47999158959136...  33.479992 -112.075859
# 7   [{'label': 'display', 'lat': 33.48093620611927...  33.480936 -112.110185
# 8   [{'label': 'display', 'lat': 33.45246120454474...  33.452461 -112.069435
# 9   [{'label': 'display', 'lat': 33.510599, 'lng':...  33.510599 -112.029753
# 10  [{'label': 'display', 'lat': 33.4832930833357,...  33.483293 -111.926579
# 11  [{'label': 'display', 'lat': 33.488436, 'lng':...  33.488436 -112.082476
# 12  [{'label': 'display', 'lat': 33.4214432017089,...  33.421443 -111.942493
# 13  [{'label': 'display', 'lat': 33.42119849782374...  33.421198 -111.925059
# 14  [{'label': 'display', 'lat': 33.4956091, 'lng'...  33.495609 -112.020032
# 15  [{'label': 'display', 'lat': 33.480027, 'lng':...  33.480027 -111.996145
# 16  [{'label': 'display', 'lat': 33.390869, 'lng':...  33.390869 -112.074627
# 17  [{'label': 'display', 'lat': 33.50854971778468...  33.508550 -112.094465
# 18  [{'label': 'display', 'lat': 33.433006, 'lng':...  33.433006 -111.903130
# 19  [{'label': 'display', 'lat': 33.46621692180633...  33.466217 -112.153469
# 20  [{'label': 'display', 'lat': 33.42610730368834...  33.426107 -111.940124
# 21  [{'label': 'display', 'lat': 33.43772984874344...  33.437730 -111.996765
# 22  [{'label': 'display', 'lat': 33.50751311172204...  33.507513 -112.040942
# 23  [{'label': 'display', 'lat': 33.3785919342333,...  33.378592 -112.028703
# 24  [{'label': 'display', 'lat': 33.537068, 'lng':...  33.537068 -112.152021
# 25  [{'label': 'display', 'lat': 33.50051, 'lng': ...  33.500510 -111.923290
# 26  [{'label': 'display', 'lat': 33.61211219177333...  33.612112 -112.169086
# 27  [{'label': 'display', 'lat': 33.41423434281571...  33.414234 -111.928943
# 28  [{'label': 'display', 'lat': 33.56702209186157...  33.567022 -112.073384
# 29  [{'label': 'display', 'lat': 33.40724786590066...  33.407248 -111.927171
# 30  [{'label': 'display', 'lat': 33.465398, 'lng':...  33.465398 -111.916691
# 31  [{'label': 'display', 'lat': 33.580558, 'lng':...  33.580558 -112.206319
# 32  [{'label': 'display', 'lat': 33.59971392636252...  33.599714 -111.982260
# 33  [{'label': 'display', 'lat': 33.47890295397645...  33.478903 -111.909347
# 34  [{'label': 'display', 'lat': 33.494128, 'lng':...  33.494128 -112.204508
# 35  [{'label': 'display', 'lat': 33.42425779859654...  33.424258 -111.939537
# 36  [{'label': 'display', 'lat': 33.57431, 'lng': ...  33.574310 -112.125745
# 37  [{'label': 'display', 'lat': 33.377489, 'lng':...  33.377489 -111.908294
# 38  [{'label': 'display', 'lat': 33.39406686290346...  33.394067 -111.875157
# 39  [{'label': 'display', 'lat': 33.48517901653316...  33.485179 -111.908423
# 40  [{'label': 'display', 'lat': 33.3629126567022,...  33.362913 -111.877470
# 41  [{'label': 'display', 'lat': 33.578008, 'lng':...  33.578008 -111.926876
# 42  [{'label': 'display', 'lat': 33.31135611600117...  33.311356 -111.859660
# 43  [{'label': 'display', 'lat': 33.36334835991079...  33.363348 -111.926913
# 44  [{'label': 'display', 'lat': 33.58027376786494...  33.580274 -112.221028
# 45  [{'label': 'display', 'lat': 33.305964, 'lng':...  33.305964 -111.942242
# 46  [{'label': 'display', 'lat': 33.27762782031286...  33.277628 -111.875696
# 47  [{'label': 'display', 'lat': 33.299807, 'lng':...  33.299807 -111.898881
# 48  [{'label': 'display', 'lat': 33.466123, 'lng':...  33.466123 -112.278459
# 49  [{'label': 'display', 'lat': 33.6114231, 'lng'...  33.611423 -112.110129
#
#    postalCode state                        id
# 0       85003    AZ  531bba89498e8d2162be9ef8
# 1       85004    AZ  4f11e94ae4b0f2c211ea1912
# 2       85004    AZ  4fc28d75e4b0524b5cc46ab0
# 3       85004    AZ  4b7f4857f964a520b92430e3
# 4       85004    AZ  4f2c23ace4b0dd6b77c536bd
# 5       85004    AZ  4bfec16ee584c9285b2f6d25
# 6       85013    AZ  4a8efca0f964a520761320e3
# 7       85015    AZ  4a7b9b2df964a52086eb1fe3
# 8       85004    AZ  534c3910498ea95153e68115
# 9       85016    AZ  413ba880f964a520221b1fe3
# 10      85251    AZ  4b05e467f964a5203ce522e3
# 11      85013    AZ  4c464825cd5ca593be6b0087
# 12      85281    AZ  4b5e6909f964a520818d29e3
# 13      85281    AZ  4b62c2fef964a5209f512ae3
# 14      85016    AZ  4ce862d2595cb1f77799c814
# 15      85018    AZ  4b8327c4f964a520befa30e3
# 16      85041    AZ  4b9b1ab8f964a52001f335e3
# 17      85015    AZ  4c9423f36b35a14307f618dc
# 18      85281    AZ  4a2ed00ff964a5205d981fe3
# 19      85035    AZ  4ba42eb6f964a520bd8938e3
# 20      85281    AZ  532d2102498e17447218942c
# 21      85034    AZ  5100a5fce4b058a37daa7b68
# 22      85016    AZ  4b1c59b4f964a5206c0624e3
# 23      85042    AZ  4c05a7e28f8fa593cc39f20d
# 24      85301    AZ  4be77720ee96c9280018fdbf
# 25      85251    AZ  4bcbaa6fcc8cd13acaeabfcf
# 26      85306    AZ  4bd6841c5631c9b6740ca630
# 27      85281    AZ  4bee1d756c5c952159f5068a
# 28      85020    AZ  4c1edab7fcf8c9b6faf3ad0b
# 29      85282    AZ  4b64a01ff964a52060c32ae3
# 30      85257    AZ  4c338e1c3896e21ec53aea90
# 31      85345    AZ  4b0045c9f964a520323c22e3
# 32      85032    AZ  4dd3fb1b091afbe9b9cce360
# 33      85251    AZ  4baac656f964a520d4853ae3
# 34      85033    AZ  4adaae3ef964a520082421e3
# 35      85281    AZ  4a85b24ff964a520f1fe1fe3
# 36      85051    AZ  4ae5eb15f964a52026a321e3
# 37      85282    AZ  4bea000261aca5938a508300
# 38      85202    AZ  4b4c91dcf964a5206ab626e3
# 39      85257    AZ  4b6cdd8af964a520165a2ce3
# 40      85202    AZ  4b00adc2f964a520884022e3
# 41      85253    AZ  4b463d99f964a5201f1b26e3
# 42      85224    AZ  4b4cbd61f964a520b3bc26e3
# 43      85283    AZ  4bbe8a5f85fbb71324037167
# 44      85345    AZ  559f253e498e2286fab5e979
# 45      85226    AZ  4bafa21bf964a52007123ce3
# 46      85286    AZ  4d56d970ba5b224b6a1d2014
# 47      85226    AZ  4b591cf1f964a520327d28e3
# 48      85392    AZ  4b214d1cf964a520d03924e3
# 49      85023    AZ  4b1eade6f964a520b11d24e3

# %%
dataframe_filtered.name
# Out:
# 0         Pizza Studio - Cityscape
# 1            Downtown Pizza Lounge
# 2        Streets Of New York Pizza
# 3               Brooklyn NYC Pizza
# 4                     Pizza People
# 5                        Pizza Hut
# 6           Pino's Pizza al Centro
# 7                    Pizza a Metro
# 8                       Boka Pizza
# 9         California Pizza Kitchen
# 10          Oregano's Pizza Bistro
# 11               Peter Piper Pizza
# 12           Otto Pizza and Pastry
# 13      Gus's New York Style Pizza
# 14               Papa John's Pizza
# 15               Peter Piper Pizza
# 16               Peter Piper Pizza
# 17            Little Caesars Pizza
# 18        California Pizza Kitchen
# 19            Little Caesars Pizza
# 20                 414 Pub & Pizza
# 21            New York Pizza Dept.
# 22                      NYPD Pizza
# 23            Little Caesars Pizza
# 24               Peter Piper Pizza
# 25            Joe's New York Pizza
# 26          Pullanos Pizza & Wings
# 27                  Domino's Pizza
# 28            Little Caesars Pizza
# 29            Little Caesars Pizza
# 30               Peter Piper Pizza
# 31               Peter Piper Pizza
# 32          Oregano's Pizza Bistro
# 33            Little Caesars Pizza
# 34               Peter Piper Pizza
# 35                    Slices Pizza
# 36               Peter Piper Pizza
# 37               Peter Piper Pizza
# 38          Oregano's Pizza Bistro
# 39            Little Chicago Pizza
# 40    Buono's New York Style Pizza
# 41        California Pizza Kitchen
# 42       Floridino's Pizza & Pasta
# 43            Little Caesars Pizza
# 44                  Don's NY Pizza
# 45           Taco Bell / Pizza Hut
# 46          Oregano's Pizza Bistro
# 47        California Pizza Kitchen
# 48               Peter Piper Pizza
# 49                   Barro's Pizza
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around the Conrad Hotel

# add a red circle marker to represent Pizzeria Bianco
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Pizzeria Bianco',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the pizza restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
